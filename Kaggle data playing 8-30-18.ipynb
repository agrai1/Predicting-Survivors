# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline
# Out:
# /Users/analeegraig/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/analeegraig/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(x='Survived', hue='Sex', data=df)

# %%
sns.countplot(x='Survived',hue='Pclass',data=df)

# %%
sns.countplot(x='Pclass',data=df)

# %%
sns.countplot(x='Survived',hue='Embarked',data=df)

# %%
sns.countplot(x='Pclass',hue='Embarked',data=df)

# %%
df[df['Sex']=='male'].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   577.000000  577.000000  577.000000  453.000000  577.000000
# mean    454.147314    0.188908    2.389948   30.726645    0.429809
# std     257.486139    0.391775    0.813580   14.678201    1.061811
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.000000    0.000000    2.000000   21.000000    0.000000
# 50%     464.000000    0.000000    3.000000   29.000000    0.000000
# 75%     680.000000    0.000000    3.000000   39.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  577.000000  577.000000
# mean     0.235702   25.523893
# std      0.612294   43.138263
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   10.500000
# 75%      0.000000   26.550000
# max      5.000000  512.329200

# %%
# 3 columns with null values:
    # age
    # cabin
    # embarked
    
# Need to figure out how many null values we have and if we can insert real values into them

# %%
# Figuring out how many null values are in age:

df[df['Age'].isnull()].describe()

# there are 177 null values for age out of 891 total people - about 20% of the dataset
# Out:
#        PassengerId    Survived      Pclass  Age       SibSp       Parch  \
# count   177.000000  177.000000  177.000000  0.0  177.000000  177.000000
# mean    435.581921    0.293785    2.598870  NaN    0.564972    0.180791
# std     250.552901    0.456787    0.763216  NaN    1.626316    0.534145
# min       6.000000    0.000000    1.000000  NaN    0.000000    0.000000
# 25%     230.000000    0.000000    3.000000  NaN    0.000000    0.000000
# 50%     452.000000    0.000000    3.000000  NaN    0.000000    0.000000
# 75%     634.000000    1.000000    3.000000  NaN    0.000000    0.000000
# max     889.000000    1.000000    3.000000  NaN    8.000000    2.000000
#
#              Fare
# count  177.000000
# mean    22.158567
# std     31.874608
# min      0.000000
# 25%      7.750000
# 50%      8.050000
# 75%     24.150000
# max    227.525000

# %%
# Null values for embarked = 2

df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# Null values for cabin = 687 or ~77% of the dataset

df[df['Cabin'].isnull()].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   687.000000  687.000000  687.000000  529.000000  687.000000
# mean    443.208151    0.299854    2.639010   27.555293    0.547307
# std     259.215905    0.458528    0.589602   13.472634    1.207492
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     214.500000    0.000000    2.000000   19.000000    0.000000
# 50%     441.000000    0.000000    3.000000   26.000000    0.000000
# 75%     664.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   74.000000    8.000000
#
#             Parch        Fare
# count  687.000000  687.000000
# mean     0.365357   19.157325
# std      0.827106   28.663343
# min      0.000000    0.000000
# 25%      0.000000    7.877100
# 50%      0.000000   10.500000
# 75%      0.000000   23.000000
# max      6.000000  512.329200

# %%
# Can I do anything about null values for cabin?

    # put a pin in it
    
    # just replace with most popular embarked site which is S

# %%
# Dealing with null values for embarked:

df['Embarked'].fillna(value='S',inplace=True)

# %%
# Check if worked

df[df['Embarked'].isnull() == True]

# success
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# Creating a title column

df['Title'] = df['Name'].apply(lambda name: name.split(',')[1])
df['Title'] = df['Title'].apply(lambda title: title.split()[0])

# %%
# Fixing Title column

df['Title'].value_counts()
# Out:
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Mlle.          2
# Major.         2
# Jonkheer.      1
# Don.           1
# Ms.            1
# the            1
# Mme.           1
# Capt.          1
# Lady.          1
# Sir.           1
# Name: Title, dtype: int64

# %%
# Check if relationship btwn title and age
plt.figure(figsize=(9, 5))

sns.stripplot(x='Title',y='Age',jitter=False,data=df)

# %%
# Biggest takeaway from title and age column is that masters are under 12

    # when filling age column nulls will fill the masters with median of masters before
        # filling in the rest of the age values as I did previously

# %%
titanic_pclass1 = df[df['Pclass'] == 1]
titanic_pclass2 = df[df['Pclass'] == 2]
titanic_pclass3 = df[df['Pclass'] == 3]

# %%
# Check if there's relationship between class and age

    # use this to fill in missing age values

# %%
sns.violinplot(x='Pclass',y='Age',data=df)

# not much variance for the ages of 3rd class individual (could be because most missing datapoints are from 3rd class age)
# Out:
# /Users/analeegraig/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(10,7))
sns.violinplot(x='Survived',y='Age',hue='Pclass',data=df)

# those who survived were typically younger in their particular class
    # this effect seems the most dramatic in first class
    # this effect could also be due partially to the fact that women were typically younger and
        # survived at higher rates
# Out:
# /Users/analeegraig/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Before I fill in null age values I want to fill in missing age values for masters

df[(df['Title'] == 'Master.') & (df['Age'].isnull() == False)].describe()

    # median = 3.5, use that to fill in missing age for Masters
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count    36.000000  36.000000  36.000000  36.000000  36.000000  36.000000
# mean    430.166667   0.583333   2.583333   4.574167   2.194444   1.388889
# std     302.915783   0.500000   0.649175   3.619872   1.737312   0.549170
# min       8.000000   0.000000   1.000000   0.420000   0.000000   0.000000
# 25%     170.500000   0.000000   2.000000   1.000000   1.000000   1.000000
# 50%     368.000000   1.000000   3.000000   3.500000   1.000000   1.000000
# 75%     788.250000   1.000000   3.000000   8.000000   4.000000   2.000000
# max     870.000000   1.000000   3.000000  12.000000   5.000000   2.000000
#
#              Fare
# count   36.000000
# mean    35.072686
# std     28.599412
# min      8.516700
# 25%     20.081250
# 50%     29.125000
# 75%     39.171875
# max    151.550000

# %%
# Filling in age for masters

df.loc[df['Age'].isnull() & (df['Title'] == 'Master.'), 'Age'] = df.loc[(df['Title'] == 'Master.'), 'Age'].median()

# %%
# Check that it worked

df[(df['Title'] == 'Master.') & (df['Age'].isnull() == True)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title]
# Index: []

# %%
# Checking relationship between age and class for men in 1st class:

df[(df['Pclass'] == 1) & (df['Sex'] == 'male')].describe()

    # Take away:
        # median close to mean --> 
            # fill in with 40.5
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   122.000000  122.000000   122.0  101.000000  122.000000  122.000000
# mean    455.729508    0.368852     1.0   41.281386    0.311475    0.278689
# std     247.026449    0.484484     0.0   15.139570    0.546695    0.658853
# min       7.000000    0.000000     1.0    0.920000    0.000000    0.000000
# 25%     255.500000    0.000000     1.0   30.000000    0.000000    0.000000
# 50%     480.500000    0.000000     1.0   40.000000    0.000000    0.000000
# 75%     660.750000    1.000000     1.0   51.000000    1.000000    0.000000
# max     890.000000    1.000000     1.0   80.000000    3.000000    4.000000
#
#              Fare
# count  122.000000
# mean    67.226127
# std     77.548021
# min      0.000000
# 25%     27.728100
# 50%     41.262500
# 75%     78.459375
# max    512.329200

# %%
# Filling in male, 1st class age with median:

df.loc[df['Age'].isnull() & (df['Sex'] == 'male') & (df['Pclass'] == 1), 'Age'] = df.loc[(df['Sex'] == 'male') & (df['Pclass'] == 1), 'Age'].mean()

# %%
# Checking to see if it worked:

df[(df['Pclass'] == 1) & (df['Sex'] == 'male') & (df['Age'].isnull())]

    # success
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title]
# Index: []

# %%
# Checking relationship between age and class for men in 2nd class:

df[(df['Pclass'] == 2) & (df['Sex'] == 'male')].describe()

# mean = median: update age with median age 30.5 (rounded to show estimated)
# Out:
#        PassengerId    Survived  Pclass        Age       SibSp       Parch  \
# count   108.000000  108.000000   108.0  99.000000  108.000000  108.000000
# mean    447.962963    0.157407     2.0  30.740707    0.342593    0.222222
# std     256.922546    0.365882     0.0  14.793894    0.566380    0.517603
# min      18.000000    0.000000     2.0   0.670000    0.000000    0.000000
# 25%     225.750000    0.000000     2.0  23.000000    0.000000    0.000000
# 50%     416.500000    0.000000     2.0  30.000000    0.000000    0.000000
# 75%     677.500000    0.000000     2.0  36.750000    1.000000    0.000000
# max     887.000000    1.000000     2.0  70.000000    2.000000    2.000000
#
#              Fare
# count  108.000000
# mean    19.741782
# std     14.922235
# min      0.000000
# 25%     12.331250
# 50%     13.000000
# 75%     26.000000
# max     73.500000

# %%
# Update age column for 2nd class men

df.loc[df['Age'].isnull() & (df['Sex'] == 'male') & (df['Pclass'] == 2), 'Age'] = df.loc[(df['Sex'] == 'male') & (df['Pclass'] == 2), 'Age'].mean()

# %%
# Check it works:

df[(df['Pclass'] == 2) & (df['Sex'] == 'male') & (df['Age'].isnull())]

# success
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title]
# Index: []

# %%
# Checking relationship between age and class for men in 3rd class:

df[(df['Pclass'] == 3) & (df['Sex'] == 'male')].describe()

# mean close to median - replace with median = 25.5 (rounded bc estimation)
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   347.000000  347.000000   347.0  257.000000  347.000000  347.000000
# mean    455.515850    0.135447     3.0   26.149494    0.498559    0.224784
# std     261.921251    0.342694     0.0   12.397012    1.288846    0.623404
# min       1.000000    0.000000     3.0    0.420000    0.000000    0.000000
# 25%     209.500000    0.000000     3.0   19.000000    0.000000    0.000000
# 50%     466.000000    0.000000     3.0   25.000000    0.000000    0.000000
# 75%     687.500000    0.000000     3.0   33.000000    0.000000    0.000000
# max     891.000000    1.000000     3.0   74.000000    8.000000    5.000000
#
#              Fare
# count  347.000000
# mean    12.661633
# std     11.681696
# min      0.000000
# 25%      7.750000
# 50%      7.925000
# 75%     10.008300
# max     69.550000

# %%
# Update missing age of 3rd class men:

df.loc[df['Age'].isnull() & (df['Sex'] == 'male') & (df['Pclass'] == 3), 'Age'] = df.loc[(df['Sex'] == 'male') & (df['Pclass'] == 3), 'Age'].mean()

# %%
# check if works:

df[(df['Pclass'] == 3) & (df['Sex'] == 'male') & (df['Age'].isnull())]

# success
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title]
# Index: []

# %%
# Check relationship btwn age in 1st class in women:

df[(df['Pclass'] == 1) & (df['Sex'] == 'female')].describe()

# mean close to median, use 35.5 to indicate estimation
# Out:
#        PassengerId   Survived  Pclass        Age      SibSp      Parch  \
# count    94.000000  94.000000    94.0  85.000000  94.000000  94.000000
# mean    469.212766   0.968085     1.0  34.611765   0.553191   0.457447
# std     247.476723   0.176716     0.0  13.612052   0.665865   0.728305
# min       2.000000   0.000000     1.0   2.000000   0.000000   0.000000
# 25%     293.500000   1.000000     1.0  23.000000   0.000000   0.000000
# 50%     447.000000   1.000000     1.0  35.000000   0.000000   0.000000
# 75%     698.250000   1.000000     1.0  44.000000   1.000000   1.000000
# max     888.000000   1.000000     1.0  63.000000   3.000000   2.000000
#
#              Fare
# count   94.000000
# mean   106.125798
# std     74.259988
# min     25.929200
# 25%     57.244800
# 50%     82.664550
# 75%    134.500000
# max    512.329200

# %%
# Update missing age for 1st class women:

df.loc[df['Age'].isnull() & (df['Sex'] == 'female') & (df['Pclass'] ==1), 'Age'] = df.loc[(df['Sex'] == 'female') & (df['Pclass'] == 1), 'Age'].mean()

# %%
# Check: 

df[(df['Pclass'] == 1) & (df['Sex'] == 'female') & (df['Age'].isnull())]

# success
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title]
# Index: []

# %%
# Check relationship between 2nd class women and age:

df[(df['Pclass'] == 2) & (df['Sex'] == 'female')].describe()

# avg age almost same as median -> use 28.5
# Out:
#        PassengerId   Survived  Pclass        Age      SibSp      Parch  \
# count    76.000000  76.000000    76.0  74.000000  76.000000  76.000000
# mean    443.105263   0.921053     2.0  28.722973   0.486842   0.605263
# std     243.627288   0.271448     0.0  12.872702   0.642774   0.833930
# min      10.000000   0.000000     2.0   2.000000   0.000000   0.000000
# 25%     269.750000   1.000000     2.0  22.250000   0.000000   0.000000
# 50%     439.500000   1.000000     2.0  28.000000   0.000000   0.000000
# 75%     616.750000   1.000000     2.0  36.000000   1.000000   1.000000
# max     881.000000   1.000000     2.0  57.000000   3.000000   3.000000
#
#             Fare
# count  76.000000
# mean   21.970121
# std    10.891796
# min    10.500000
# 25%    13.000000
# 50%    22.000000
# 75%    26.062500
# max    65.000000

# %%
# Update age for 2nd class women:

df.loc[df['Age'].isnull() & (df['Sex'] == 'female') & (df['Pclass'] ==2), 'Age'] = df.loc[(df['Sex'] == 'female') & (df['Pclass'] == 2), 'Age'].mean()

# %%
# Check

df[(df['Pclass'] == 1) & (df['Sex'] == 'female') & (df['Age'].isnull())]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title]
# Index: []

# %%
# Check age for 3rd class women:

df[(df['Sex'] == 'female') & (df['Pclass'] == 3)].describe()

# age basically same as median - use 21.5 to indicate estimation
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   144.000000  144.000000   144.0  102.000000  144.000000  144.000000
# mean    399.729167    0.500000     3.0   21.750000    0.895833    0.798611
# std     267.232416    0.501745     0.0   12.729964    1.531573    1.237976
# min       3.000000    0.000000     3.0    0.750000    0.000000    0.000000
# 25%     165.250000    0.000000     3.0   14.125000    0.000000    0.000000
# 50%     376.000000    0.500000     3.0   21.500000    0.000000    0.000000
# 75%     636.000000    1.000000     3.0   29.750000    1.000000    1.000000
# max     889.000000    1.000000     3.0   63.000000    8.000000    6.000000
#
#              Fare
# count  144.000000
# mean    16.118810
# std     11.690314
# min      6.750000
# 25%      7.854200
# 50%     12.475000
# 75%     20.221875
# max     69.550000

# %%
# update missing age for 3rd class women:

df.loc[df['Age'].isnull() & (df['Sex'] == 'female') & (df['Pclass'] == 3), 'Age'] = df.loc[(df['Sex'] == 'female') & (df['Pclass'] == 3), 'Age'].mean()

# %%
# check

df[(df['Pclass'] == 1) & (df['Sex'] == 'female') & (df['Age'].isnull())]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title]
# Index: []

# %%
# Making Adult Male column

df['Adult Male'] = (df['Sex'] == 'male') & (df['Age'] > 18)

# %%
# Investigating Relationship between survival and family size:

# %%
df['Family Size'] = df['SibSp'] + df['Parch']

# %%
plt.figure(figsize=(12,8))

sns.countplot(x='Survived',hue='Family Size',data=df)

plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)

# %%
df['Family present'] = df['Family Size'] > 0

# %%
sns.countplot(x='Survived',data=df,hue='Family present')

    # family present matters --> those with family aboard survived at a higher rate than those without

# %%
sns.countplot(x='Survived',data=df[df['Sex'] == 'female'],hue='Family present')

# for women the effect of family members aboard on survival doesn't seem significant

# what's a good way to isolate this relationship?

# %%
sns.countplot(x='Survived',data=df[df['Sex'] == 'male'],hue='Family present')

# men with family members on board died at a lower rate than men without families aboard

# %%
sns.distplot(df['Age'])

# not a ...super weird distribution plot. it .... vaguely makes sense.
# Out:
# /Users/analeegraig/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.179183
# std       13.399449
# min        0.420000
# 25%       21.750000
# 50%       26.149494
# 75%       36.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Investigating cabin column

# %%
df['Cabin'].value_counts().head()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# D              3
# E101           3
# Name: Cabin, dtype: int64

# %%
df['Has Cabin'] = df['Cabin'].isnull() == False

# %%
sns.countplot(x='Survived',hue='Has Cabin',data=df)

# seems like there is a relationship between having a cabin and surival (possibly related to class)

# %%
sns.countplot(x='Pclass',hue='Has Cabin',data=df)

# Yeah, first class people have a cabin at a much, much higher rate then any other class
    # kind of interesting that 2nd class people don't seem to have a huge rate of having cabins

# %%
df_male_pclass3 = pd.DataFrame(df[(df['Pclass'] == 3) & (df['Sex'] == 'male')])

# %%
df_male_pclass3
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 26            27         0       3                  Emir, Mr. Farred Chehab
# 29            30         0       3                      Todoroff, Mr. Lalio
# 36            37         1       3                         Mamee, Mr. Hanna
# 37            38         0       3                 Cann, Mr. Ernest Charles
# 42            43         0       3                      Kraeff, Mr. Theodor
# 45            46         0       3                 Rogers, Mr. William John
# 46            47         0       3                        Lennon, Mr. Denis
# 48            49         0       3                      Samaan, Mr. Youssef
# 50            51         0       3               Panula, Master. Juha Niilo
# 51            52         0       3             Nosworthy, Mr. Richard Cater
# 57            58         0       3                      Novel, Mr. Mansouer
# 59            60         0       3       Goodwin, Master. William Frederick
# 60            61         0       3                    Sirayanian, Mr. Orsen
# 63            64         0       3                    Skoog, Master. Harald
# 65            66         1       3                 Moubarek, Master. Gerios
# 67            68         0       3                 Crease, Mr. Ernest James
# 69            70         0       3                        Kink, Mr. Vincenz
# 73            74         0       3              Chronopoulos, Mr. Apostolos
# 74            75         1       3                            Bing, Mr. Lee
# 75            76         0       3                  Moen, Mr. Sigurd Hansen
# 76            77         0       3                        Staneff, Mr. Ivan
# 77            78         0       3                 Moutal, Mr. Rahamin Haim
# 80            81         0       3                     Waelens, Mr. Achille
# ..           ...       ...     ...                                      ...
# 824          825         0       3             Panula, Master. Urho Abraham
# 825          826         0       3                          Flynn, Mr. John
# 826          827         0       3                             Lam, Mr. Len
# 828          829         1       3             McCormack, Mr. Thomas Joseph
# 832          833         0       3                           Saad, Mr. Amin
# 833          834         0       3                   Augustsson, Mr. Albert
# 834          835         0       3                   Allum, Mr. Owen George
# 836          837         0       3                         Pasic, Mr. Jakob
# 837          838         0       3                      Sirota, Mr. Maurice
# 838          839         1       3                          Chip, Mr. Chang
# 840          841         0       3              Alhomaki, Mr. Ilmari Rudolf
# 843          844         0       3               Lemberopolous, Mr. Peter L
# 844          845         0       3                      Culumovic, Mr. Jeso
# 845          846         0       3                      Abbing, Mr. Anthony
# 846          847         0       3                 Sage, Mr. Douglas Bullen
# 847          848         0       3                       Markoff, Mr. Marin
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 851          852         0       3                      Svensson, Mr. Johan
# 859          860         0       3                         Razi, Mr. Raihed
# 860          861         0       3                  Hansen, Mr. Claus Peter
# 868          869         0       3              van Melkebeke, Mr. Philemon
# 869          870         1       3          Johnson, Master. Harold Theodor
# 870          871         0       3                        Balkic, Mr. Cerin
# 873          874         0       3              Vander Cruyssen, Mr. Victor
# 876          877         0       3            Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                     Petroff, Mr. Nedelio
# 878          879         0       3                       Laleff, Mr. Kristo
# 881          882         0       3                       Markun, Mr. Johann
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 890          891         0       3                      Dooley, Mr. Patrick
#
#       Sex        Age  SibSp  Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.000000      1      0         A/5 21171   7.2500    NaN        S
# 4    male  35.000000      0      0            373450   8.0500    NaN        S
# 5    male  26.149494      0      0            330877   8.4583    NaN        Q
# 7    male   2.000000      3      1            349909  21.0750    NaN        S
# 12   male  20.000000      0      0         A/5. 2151   8.0500    NaN        S
# 13   male  39.000000      1      5            347082  31.2750    NaN        S
# 16   male   2.000000      4      1            382652  29.1250    NaN        Q
# 26   male  26.149494      0      0              2631   7.2250    NaN        C
# 29   male  26.149494      0      0            349216   7.8958    NaN        S
# 36   male  26.149494      0      0              2677   7.2292    NaN        C
# 37   male  21.000000      0      0        A./5. 2152   8.0500    NaN        S
# 42   male  26.149494      0      0            349253   7.8958    NaN        C
# 45   male  26.149494      0      0   S.C./A.4. 23567   8.0500    NaN        S
# 46   male  26.149494      1      0            370371  15.5000    NaN        Q
# 48   male  26.149494      2      0              2662  21.6792    NaN        C
# 50   male   7.000000      4      1           3101295  39.6875    NaN        S
# 51   male  21.000000      0      0        A/4. 39886   7.8000    NaN        S
# 57   male  28.500000      0      0              2697   7.2292    NaN        C
# 59   male  11.000000      5      2           CA 2144  46.9000    NaN        S
# 60   male  22.000000      0      0              2669   7.2292    NaN        C
# 63   male   4.000000      3      2            347088  27.9000    NaN        S
# 65   male   3.500000      1      1              2661  15.2458    NaN        C
# 67   male  19.000000      0      0         S.P. 3464   8.1583    NaN        S
# 69   male  26.000000      2      0            315151   8.6625    NaN        S
# 73   male  26.000000      1      0              2680  14.4542    NaN        C
# 74   male  32.000000      0      0              1601  56.4958    NaN        S
# 75   male  25.000000      0      0            348123   7.6500  F G73        S
# 76   male  26.149494      0      0            349208   7.8958    NaN        S
# 77   male  26.149494      0      0            374746   8.0500    NaN        S
# 80   male  22.000000      0      0            345767   9.0000    NaN        S
# ..    ...        ...    ...    ...               ...      ...    ...      ...
# 824  male   2.000000      4      1           3101295  39.6875    NaN        S
# 825  male  26.149494      0      0            368323   6.9500    NaN        Q
# 826  male  26.149494      0      0              1601  56.4958    NaN        S
# 828  male  26.149494      0      0            367228   7.7500    NaN        Q
# 832  male  26.149494      0      0              2671   7.2292    NaN        C
# 833  male  23.000000      0      0            347468   7.8542    NaN        S
# 834  male  18.000000      0      0              2223   8.3000    NaN        S
# 836  male  21.000000      0      0            315097   8.6625    NaN        S
# 837  male  26.149494      0      0            392092   8.0500    NaN        S
# 838  male  32.000000      0      0              1601  56.4958    NaN        S
# 840  male  20.000000      0      0  SOTON/O2 3101287   7.9250    NaN        S
# 843  male  34.500000      0      0              2683   6.4375    NaN        C
# 844  male  17.000000      0      0            315090   8.6625    NaN        S
# 845  male  42.000000      0      0         C.A. 5547   7.5500    NaN        S
# 846  male  26.149494      8      2          CA. 2343  69.5500    NaN        S
# 847  male  35.000000      0      0            349213   7.8958    NaN        C
# 850  male   4.000000      4      2            347082  31.2750    NaN        S
# 851  male  74.000000      0      0            347060   7.7750    NaN        S
# 859  male  26.149494      0      0              2629   7.2292    NaN        C
# 860  male  41.000000      2      0            350026  14.1083    NaN        S
# 868  male  26.149494      0      0            345777   9.5000    NaN        S
# 869  male   4.000000      1      1            347742  11.1333    NaN        S
# 870  male  26.000000      0      0            349248   7.8958    NaN        S
# 873  male  47.000000      0      0            345765   9.0000    NaN        S
# 876  male  20.000000      0      0              7534   9.8458    NaN        S
# 877  male  19.000000      0      0            349212   7.8958    NaN        S
# 878  male  26.149494      0      0            349217   7.8958    NaN        S
# 881  male  33.000000      0      0            349257   7.8958    NaN        S
# 884  male  25.000000      0      0   SOTON/OQ 392076   7.0500    NaN        S
# 890  male  32.000000      0      0            370376   7.7500    NaN        Q
#
#        Title  Adult Male  Family Size  Family present  Has Cabin
# 0        Mr.        True            1            True      False
# 4        Mr.        True            0           False      False
# 5        Mr.        True            0           False      False
# 7    Master.       False            4            True      False
# 12       Mr.        True            0           False      False
# 13       Mr.        True            6            True      False
# 16   Master.       False            5            True      False
# 26       Mr.        True            0           False      False
# 29       Mr.        True            0           False      False
# 36       Mr.        True            0           False      False
# 37       Mr.        True            0           False      False
# 42       Mr.        True            0           False      False
# 45       Mr.        True            0           False      False
# 46       Mr.        True            1            True      False
# 48       Mr.        True            2            True      False
# 50   Master.       False            5            True      False
# 51       Mr.        True            0           False      False
# 57       Mr.        True            0           False      False
# 59   Master.       False            7            True      False
# 60       Mr.        True            0           False      False
# 63   Master.       False            5            True      False
# 65   Master.       False            2            True      False
# 67       Mr.        True            0           False      False
# 69       Mr.        True            2            True      False
# 73       Mr.        True            1            True      False
# 74       Mr.        True            0           False      False
# 75       Mr.        True            0           False       True
# 76       Mr.        True            0           False      False
# 77       Mr.        True            0           False      False
# 80       Mr.        True            0           False      False
# ..       ...         ...          ...             ...        ...
# 824  Master.       False            5            True      False
# 825      Mr.        True            0           False      False
# 826      Mr.        True            0           False      False
# 828      Mr.        True            0           False      False
# 832      Mr.        True            0           False      False
# 833      Mr.        True            0           False      False
# 834      Mr.       False            0           False      False
# 836      Mr.        True            0           False      False
# 837      Mr.        True            0           False      False
# 838      Mr.        True            0           False      False
# 840      Mr.        True            0           False      False
# 843      Mr.        True            0           False      False
# 844      Mr.       False            0           False      False
# 845      Mr.        True            0           False      False
# 846      Mr.        True           10            True      False
# 847      Mr.        True            0           False      False
# 850  Master.       False            6            True      False
# 851      Mr.        True            0           False      False
# 859      Mr.        True            0           False      False
# 860      Mr.        True            2            True      False
# 868      Mr.        True            0           False      False
# 869  Master.       False            2            True      False
# 870      Mr.        True            0           False      False
# 873      Mr.        True            0           False      False
# 876      Mr.        True            0           False      False
# 877      Mr.        True            0           False      False
# 878      Mr.        True            0           False      False
# 881      Mr.        True            0           False      False
# 884      Mr.        True            0           False      False
# 890      Mr.        True            0           False      False
#
# [347 rows x 17 columns]

# %%
# Does this just look super weird for a distribution? The KDE looks ... sort of normal

sns.distplot(df_male_pclass3['Age'])
# Out:
# /Users/analeegraig/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Convert categorical features into dummy variables:

# %%
sex = pd.get_dummies(df['Sex'],drop_first=True)

# %%
embark = pd.get_dummies(df['Embarked'],drop_first=True)

# %%
pclass = pd.get_dummies(df['Pclass'],drop_first=True)

# %%
df = pd.concat([df,embark,pclass,sex],axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ...   Title Adult Male Family Size  \
# 0      0         A/5 21171   7.2500  ...     Mr.       True           1
# 1      0          PC 17599  71.2833  ...    Mrs.      False           1
# 2      0  STON/O2. 3101282   7.9250  ...   Miss.      False           0
# 3      0            113803  53.1000  ...    Mrs.      False           1
# 4      0            373450   8.0500  ...     Mr.       True           0
#
#    Family present  Has Cabin  Q  S  2  3  male
# 0            True      False  0  1  0  1     1
# 1            True       True  0  0  0  0     0
# 2           False      False  0  1  0  1     0
# 3            True       True  0  1  0  0     0
# 4           False      False  0  1  0  1     1
#
# [5 rows x 22 columns]

# %%
df.drop(['PassengerId','Name','Ticket','Embarked','Cabin','Title','Family Size','Pclass','Sex','Family present'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  Adult Male  Has Cabin  Q  S  2  3  \
# 0         0  22.0      1      0   7.2500        True      False  0  1  0  1
# 1         1  38.0      1      0  71.2833       False       True  0  0  0  0
# 2         1  26.0      0      0   7.9250       False      False  0  1  0  1
# 3         1  35.0      1      0  53.1000       False       True  0  1  0  0
# 4         0  35.0      0      0   8.0500        True      False  0  1  0  1
#
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
X = df.drop('Survived',axis=1)
y = df['Survived']

# %%
# Run model

# %%
from sklearn.cross_validation import train_test_split
# Out:
# /Users/analeegraig/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/analeegraig/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/analeegraig/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression
# Out:
# /Users/analeegraig/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.79      0.90      0.84       154
#           1       0.84      0.68      0.75       114
#
# avg / total       0.81      0.81      0.80       268

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[139  15]
#  [ 37  77]]

# %%
# Making AUC and ROC curve

# %%
import statsmodels.api as sm
from sklearn.cross_validation import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve, auc
import pylab
from sklearn import svm
import re
import pylab as plt
import seaborn
from sklearn.linear_model import LinearRegression
import numpy.random as nprnd
pd.set_option('display.max_columns', 500)
import random

# %%
# Computes the AUC ROC of the classifier.
def generate_auc(X,y,clf_class,**kwargs):
    # Construct a kfolds object
    random_state = np.random.RandomState(0)
    # Construct training and testing set.
    X, y = shuffle(X, y, random_state=random_state)
    n_samples, n_features = X.shape
    half = int(n_samples/1.2)
    X_train, X_test = X[:half], X[half:]
    y_train, y_test = y[:half], y[half:]
    
    # Choose SVC classifier.
    classifier = clf_class(**kwargs)
    probas_ = classifier.fit(X_train, y_train).predict_proba(X_test)
    
    fpr, tpr, thresholds = roc_curve(y_test, probas_[:, 1])
    roc_auc = auc(fpr, tpr)
    print("Area under the ROC curve : %f" % roc_auc)
    return fpr, tpr, roc_auc, thresholds

# Generate ROC  for LR with l1 penalty and C=0.1
fpr,tpr,roc_auc, thresholds = generate_auc(X,y,LogisticRegression,C=0.1,penalty='l1')
def generate_ROCplot(fpr,tpr,label,roc_auc):
    plt.clf()
    plt.plot(fpr, tpr, '.-',label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()
    
# Plots ROC
plt.figure(figsize=(12,8))
generate_ROCplot(fpr,tpr,'LR',roc_auc)
# Out:
# Area under the ROC curve : 0.884239
